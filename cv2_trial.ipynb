# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('apo.jpg',1)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
face = img[120:285,420:630]

# %%
plt.imshow(face)

# %%
imgcopy = img.copy()

# %%
face.shape
# Out:
# (165, 210, 3)

# %%
height,width = face.shape[:2]
print(height)
print(width)
# Out:
# 165
# 210

# %%
imgcopy[290:290+height,150:150+width] = face

# %%
plt.imshow(imgcopy)

# %%
resize1 = cv2.resize(img,None,fx = 0.6,fy = 0.6,interpolation =  cv2.INTER_LINEAR)

# %%
plt.imshow(resize1)

# %%
mask = cv2.inRange(img,(0,50,100),(100,225,225))

# %%
plt.imshow(mask)
